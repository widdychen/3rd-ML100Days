# %%
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline
import os
import requests
# Out:
# Using TensorFlow backend.
# <Response [200]>

# %%
# 此函數會幫我們把多張影像畫成一張多宮格圖
def img_combine(img, ncols=8, size=1, path=False):
    from math import ceil
    import matplotlib.pyplot as plt
    import numpy as np
    nimg = len(img)
    nrows = int(ceil(nimg/ncols))
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(ncols*size,nrows*size))
    if nrows == 0:
        return
    elif ncols == 1:
        for r, ax in zip(np.arange(nrows), axes):
            nth=r
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                
            ax.set_axis_off()
    elif nrows == 1:
        for c, ax in zip(np.arange(ncols), axes):
            nth=c
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
            ax.set_axis_off()
    else:
        for r, row in zip(np.arange(nrows), axes):
            for c, ax in zip(np.arange(ncols), row):
                nth=r*ncols+c
                if nth < nimg:
                    ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                ax.set_axis_off()
    plt.show()

# %%
# 讀取 Cifar-10 資料集
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# 取前 32 張圖片做視覺化
images = x_train[:32]
img_combine(images)

# %%
# 建立 ImageDataGenerator，並指定我們要做資料增強的數值範圍
data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %%
# 注意！！ ImageDataGenerator 是一個 Generator (生成器)! 對 Generator 不熟悉的同學請回到 Day098 做複習。
# 使用 .flow 後，就會對我們的影像進行增強，再 call next 取出 generator 的圖像。(shuffle=False 因為我們希望圖像的順序不要改變，方便觀察。實際訓練時預設是 shuffle=True) 
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int")) # 注意在訓練時神經網路時，圖像資料必須要是 float32，但在做視覺化時要轉為 int 才能順利畫圖。所以為了畫圖才把資料轉為 int

# %%
# 因為隨機性的關係，所以一樣的圖像再經過一次 generator 後的結果不一定相同
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int"))

# %% [markdown]
# ## 作業

# %% [markdown]
# 請使用 ImageDataGenerator 來進行 Cifar-10 資料集的訓練，並觀察不同的圖像增強方法是否會顯著影響訓練結果

# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import  EarlyStopping,ReduceLROnPlateau
import os

# %%
batch_size = 128 
num_classes = 10 
epochs = 50

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
from keras.applications.densenet import DenseNet121
from keras.models import Model

model = DenseNet121(include_top=False, weights=None, input_shape=(32,32,3))
output=Flatten()(model.output)
output = Dropout(0.5)(output)
output_layer = Dense(num_classes, activation='softmax', name='softmax')(output)
model = Model(inputs=model.input, outputs=output_layer)
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(lr=0.001,decay=1e-5),
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\1911141\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\1911141\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
datagen = ImageDataGenerator(featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)


history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=int(len(x_train)/batch_size),
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),callbacks=[learning_rate_reduction])
# Out:
# WARNING:tensorflow:From C:\Users\1911141\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 390/390 [==============================] - 56s 144ms/step - loss: 1.7070 - accuracy: 0.4082 - val_loss: 9.1619 - val_accuracy: 0.1365
# Epoch 2/50
# 390/390 [==============================] - 41s 105ms/step - loss: 1.4365 - accuracy: 0.5061 - val_loss: 3.0544 - val_accuracy: 0.1372
# Epoch 3/50
# 390/390 [==============================] - 41s 105ms/step - loss: 1.4088 - accuracy: 0.5228 - val_loss: 1.4816 - val_accuracy: 0.4683
# Epoch 4/50
# 390/390 [==============================] - 41s 105ms/step - loss: 1.1990 - accuracy: 0.5833 - val_loss: 11.9932 - val_accuracy: 0.3697
# Epoch 5/50
# 390/390 [==============================] - 41s 105ms/step - loss: 1.0692 - accuracy: 0.6272 - val_loss: 1.3065 - val_accuracy: 0.5730
# Epoch 6/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.9705 - accuracy: 0.6629 - val_loss: 1.3363 - val_accuracy: 0.5787
# Epoch 7/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.9389 - accuracy: 0.6764 - val_loss: 2.9676 - val_accuracy: 0.4021
# Epoch 8/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.9096 - accuracy: 0.6850 - val_loss: 0.9506 - val_accuracy: 0.6737
# Epoch 9/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.8043 - accuracy: 0.7203 - val_loss: 0.8747 - val_accuracy: 0.6927
# Epoch 10/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.7222 - accuracy: 0.7465 - val_loss: 0.8753 - val_accuracy: 0.6990
# Epoch 11/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.6699 - accuracy: 0.7669 - val_loss: 1.2411 - val_accuracy: 0.6389
# Epoch 12/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.6393 - accuracy: 0.7776 - val_loss: 1.0399 - val_accuracy: 0.6668
# Epoch 13/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.5976 - accuracy: 0.7925 - val_loss: 1.0204 - val_accuracy: 0.6865
# Epoch 14/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.6016 - accuracy: 0.7898 - val_loss: 1.2471 - val_accuracy: 0.6341
# Epoch 15/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.5458 - accuracy: 0.8115 - val_loss: 1.0484 - val_accuracy: 0.6668
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.5423 - accuracy: 0.8147 - val_loss: 0.8651 - val_accuracy: 0.7234
# Epoch 17/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.4536 - accuracy: 0.8413 - val_loss: 0.6055 - val_accuracy: 0.7971
# Epoch 18/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3961 - accuracy: 0.8607 - val_loss: 0.6281 - val_accuracy: 0.7987
# Epoch 19/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3704 - accuracy: 0.8696 - val_loss: 0.6728 - val_accuracy: 0.7838
# Epoch 20/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3500 - accuracy: 0.8776 - val_loss: 0.5952 - val_accuracy: 0.8101
# Epoch 21/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3812 - accuracy: 0.8688 - val_loss: 0.6238 - val_accuracy: 0.8017
# Epoch 22/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.3242 - accuracy: 0.8837 - val_loss: 0.6071 - val_accuracy: 0.8087
# Epoch 23/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2963 - accuracy: 0.8957 - val_loss: 0.7595 - val_accuracy: 0.7746
# Epoch 24/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2905 - accuracy: 0.8987 - val_loss: 0.7554 - val_accuracy: 0.7764
# Epoch 25/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2675 - accuracy: 0.9058 - val_loss: 0.6211 - val_accuracy: 0.8061
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2129 - accuracy: 0.9251 - val_loss: 0.6869 - val_accuracy: 0.8069
# Epoch 27/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1910 - accuracy: 0.9315 - val_loss: 0.7252 - val_accuracy: 0.8063
# Epoch 28/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.1782 - accuracy: 0.9365 - val_loss: 0.6658 - val_accuracy: 0.8156
# Epoch 29/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1729 - accuracy: 0.9397 - val_loss: 0.7089 - val_accuracy: 0.8141
# Epoch 30/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.1608 - accuracy: 0.9433 - val_loss: 0.6671 - val_accuracy: 0.8228
# Epoch 31/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1554 - accuracy: 0.9446 - val_loss: 0.8216 - val_accuracy: 0.7936
# Epoch 32/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.1495 - accuracy: 0.9479 - val_loss: 0.6850 - val_accuracy: 0.8211
# Epoch 33/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1426 - accuracy: 0.9500 - val_loss: 0.6832 - val_accuracy: 0.8212
# Epoch 34/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1313 - accuracy: 0.9535 - val_loss: 0.7469 - val_accuracy: 0.8178
# Epoch 35/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1313 - accuracy: 0.9538 - val_loss: 0.8557 - val_accuracy: 0.7897
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 36/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1040 - accuracy: 0.9638 - val_loss: 0.7074 - val_accuracy: 0.8276
# Epoch 37/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0939 - accuracy: 0.9668 - val_loss: 0.8004 - val_accuracy: 0.8142
# Epoch 38/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0910 - accuracy: 0.9686 - val_loss: 0.7462 - val_accuracy: 0.8274
# Epoch 39/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0860 - accuracy: 0.9694 - val_loss: 0.7504 - val_accuracy: 0.8279
# Epoch 40/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0844 - accuracy: 0.9707 - val_loss: 0.7970 - val_accuracy: 0.8200
# Epoch 41/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0812 - accuracy: 0.9715 - val_loss: 0.7693 - val_accuracy: 0.8296
# Epoch 42/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0792 - accuracy: 0.9716 - val_loss: 0.7736 - val_accuracy: 0.8284
# Epoch 43/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0770 - accuracy: 0.9731 - val_loss: 0.7735 - val_accuracy: 0.8266
# Epoch 44/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0739 - accuracy: 0.9739 - val_loss: 0.7961 - val_accuracy: 0.8253
# Epoch 45/50
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0736 - accuracy: 0.9749 - val_loss: 0.7947 - val_accuracy: 0.8260
# Epoch 46/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0666 - accuracy: 0.9765 - val_loss: 0.9463 - val_accuracy: 0.8071
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 47/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0598 - accuracy: 0.9789 - val_loss: 0.7748 - val_accuracy: 0.8343
# Epoch 48/50
# 390/390 [==============================] - 42s 107ms/step - loss: 0.0557 - accuracy: 0.9815 - val_loss: 0.8151 - val_accuracy: 0.8319
# Epoch 49/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0525 - accuracy: 0.9821 - val_loss: 0.8568 - val_accuracy: 0.8281
# Epoch 50/50
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0577 - accuracy: 0.9793 - val_loss: 0.8351 - val_accuracy: 0.8272

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=1)
print("Test: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# 10000/10000 [==============================] - 6s 576us/step
# Test: accuracy = 0.827200  ;  loss = 0.835094

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)
plt.show()
