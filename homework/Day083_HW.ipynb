# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import keras
import itertools
import requests
# Out:
# Using TensorFlow backend.
# <Response [200]>

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization


def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = [2, 16, 32, 128, 256]
MOMENTUM = 0.95

# %%
results = {}
for batchSize in BATCH_SIZE :
    
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()

    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              
              # different batch_size
              batch_size=batchSize, 
              
              validation_data=(x_test, y_test), 
              shuffle=True)

    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    name_tag = 'batchSize : %.2f' % batchSize
    results[name_tag] = {'train-loss': train_loss,
                         'valid-loss': valid_loss,
                         'train-acc' : train_acc,
                         'valid-acc' : valid_acc}
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\1911141\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 132s 3ms/step - loss: 2.3110 - accuracy: 0.1473 - val_loss: 2.1966 - val_accuracy: 0.1750
# Epoch 2/10
# 50000/50000 [==============================] - 128s 3ms/step - loss: 2.2339 - accuracy: 0.1686 - val_loss: 2.1556 - val_accuracy: 0.2213
# Epoch 3/10
# 50000/50000 [==============================] - 127s 3ms/step - loss: 2.2328 - accuracy: 0.1651 - val_loss: 2.1645 - val_accuracy: 0.2330
# Epoch 4/10
# 50000/50000 [==============================] - 126s 3ms/step - loss: 2.2293 - accuracy: 0.1719 - val_loss: 2.1575 - val_accuracy: 0.2237
# Epoch 5/10
# 50000/50000 [==============================] - 127s 3ms/step - loss: 2.2300 - accuracy: 0.1709 - val_loss: 2.1952 - val_accuracy: 0.2173
# Epoch 6/10
# 50000/50000 [==============================] - 126s 3ms/step - loss: 2.2235 - accuracy: 0.1736 - val_loss: 2.3147 - val_accuracy: 0.1959
# Epoch 7/10
# 50000/50000 [==============================] - 126s 3ms/step - loss: 2.2223 - accuracy: 0.1760 - val_loss: 2.4853 - val_accuracy: 0.2174
# Epoch 8/10
# 50000/50000 [==============================] - 126s 3ms/step - loss: 2.2260 - accuracy: 0.1736 - val_loss: 2.2464 - val_accuracy: 0.2255
# Epoch 9/10
# 50000/50000 [==============================] - 123s 2ms/step - loss: 2.2302 - accuracy: 0.1721 - val_loss: 2.4042 - val_accuracy: 0.2230
# Epoch 10/10
# 50000/50000 [==============================] - 123s 2ms/step - loss: 2.2287 - accuracy: 0.1703 - val_loss: 19.5304 - val_accuracy: 0.2153
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 17s 333us/step - loss: 1.8017 - accuracy: 0.3565 - val_loss: 1.6214 - val_accuracy: 0.4218
# Epoch 2/10
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.6428 - accuracy: 0.4160 - val_loss: 1.7951 - val_accuracy: 0.3674
# Epoch 3/10
# 50000/50000 [==============================] - 16s 324us/step - loss: 1.5880 - accuracy: 0.4339 - val_loss: 1.6389 - val_accuracy: 0.4262
# Epoch 4/10
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.5495 - accuracy: 0.4494 - val_loss: 1.6784 - val_accuracy: 0.4104
# Epoch 5/10
# 50000/50000 [==============================] - 16s 325us/step - loss: 1.5219 - accuracy: 0.4572 - val_loss: 1.5861 - val_accuracy: 0.4387
# Epoch 6/10
# 50000/50000 [==============================] - 16s 323us/step - loss: 1.4859 - accuracy: 0.4740 - val_loss: 1.5877 - val_accuracy: 0.4353
# Epoch 7/10
# 50000/50000 [==============================] - 16s 323us/step - loss: 1.4503 - accuracy: 0.4814 - val_loss: 1.4399 - val_accuracy: 0.4867
# Epoch 8/10
# 50000/50000 [==============================] - 16s 326us/step - loss: 1.4441 - accuracy: 0.4886 - val_loss: 1.4706 - val_accuracy: 0.4809
# Epoch 9/10
# 50000/50000 [==============================] - 16s 324us/step - loss: 1.4194 - accuracy: 0.4967 - val_loss: 1.4739 - val_accuracy: 0.4760
# Epoch 10/10
# 50000/50000 [==============================] - 16s 324us/step - loss: 1.3889 - accuracy: 0.5062 - val_loss: 1.4348 - val_accuracy: 0.4875
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 9s 177us/step - loss: 1.7371 - accuracy: 0.3849 - val_loss: 1.6098 - val_accuracy: 0.4236
# Epoch 2/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.5415 - accuracy: 0.4529 - val_loss: 1.5430 - val_accuracy: 0.4577
# Epoch 3/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.4652 - accuracy: 0.4804 - val_loss: 1.5306 - val_accuracy: 0.4523
# Epoch 4/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.4152 - accuracy: 0.4972 - val_loss: 1.5438 - val_accuracy: 0.4501
# Epoch 5/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.3733 - accuracy: 0.5121 - val_loss: 1.4521 - val_accuracy: 0.4843
# Epoch 6/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.3341 - accuracy: 0.5269 - val_loss: 1.4840 - val_accuracy: 0.4735
# Epoch 7/10
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.3093 - accuracy: 0.5369 - val_loss: 1.4724 - val_accuracy: 0.4837
# Epoch 8/10
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.2842 - accuracy: 0.5469 - val_loss: 1.5019 - val_accuracy: 0.4700
# Epoch 9/10
# 50000/50000 [==============================] - 8s 170us/step - loss: 1.2656 - accuracy: 0.5512 - val_loss: 1.4367 - val_accuracy: 0.4888
# Epoch 10/10
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.2464 - accuracy: 0.5568 - val_loss: 1.4449 - val_accuracy: 0.4933
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 4s 76us/step - loss: 1.7737 - accuracy: 0.3831 - val_loss: 1.6589 - val_accuracy: 0.4130
# Epoch 2/10
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.5012 - accuracy: 0.4717 - val_loss: 1.6079 - val_accuracy: 0.4326
# Epoch 3/10
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.4072 - accuracy: 0.5041 - val_loss: 1.5090 - val_accuracy: 0.4609
# Epoch 4/10
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.3332 - accuracy: 0.5293 - val_loss: 1.5072 - val_accuracy: 0.4746
# Epoch 5/10
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.2666 - accuracy: 0.5545 - val_loss: 1.5276 - val_accuracy: 0.4656
# Epoch 6/10
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2176 - accuracy: 0.5714 - val_loss: 1.5458 - val_accuracy: 0.4605
# Epoch 7/10
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.1683 - accuracy: 0.5904 - val_loss: 1.4521 - val_accuracy: 0.4923
# Epoch 8/10
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.1263 - accuracy: 0.6054 - val_loss: 1.4894 - val_accuracy: 0.4837
# Epoch 9/10
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0895 - accuracy: 0.6180 - val_loss: 1.6026 - val_accuracy: 0.4532
# Epoch 10/10
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0499 - accuracy: 0.6297 - val_loss: 1.5804 - val_accuracy: 0.4568
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.8746 - accuracy: 0.3562 - val_loss: 1.7505 - val_accuracy: 0.3866
# Epoch 2/10
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.5457 - accuracy: 0.4570 - val_loss: 1.5938 - val_accuracy: 0.4365
# Epoch 3/10
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4453 - accuracy: 0.4962 - val_loss: 1.5517 - val_accuracy: 0.4529
# Epoch 4/10
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.3719 - accuracy: 0.5195 - val_loss: 1.5151 - val_accuracy: 0.4620
# Epoch 5/10
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3140 - accuracy: 0.5388 - val_loss: 1.5024 - val_accuracy: 0.4688
# Epoch 6/10
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2652 - accuracy: 0.5552 - val_loss: 1.4979 - val_accuracy: 0.4710
# Epoch 7/10
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2161 - accuracy: 0.5751 - val_loss: 1.4751 - val_accuracy: 0.4738
# Epoch 8/10
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1718 - accuracy: 0.5888 - val_loss: 1.4439 - val_accuracy: 0.4900
# Epoch 9/10
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1338 - accuracy: 0.6020 - val_loss: 1.5424 - val_accuracy: 0.4703
# Epoch 10/10
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.0924 - accuracy: 0.6205 - val_loss: 1.5301 - val_accuracy: 0.4687

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ## 將 BN 放在 Activation 之前，並比較訓練結果

# %%
from keras.layers import BatchNormalization


def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            # 2. 把 BatchNormalization 放在 activation 前
            x = BatchNormalization()(input_layer)
            
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
        else:
            # 2. 把 BatchNormalization 放在 activation 前
            x = BatchNormalization()(x)
            
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model


## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = 512
MOMENTUM = 0.95

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()

optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
   
    
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,250
# Trainable params: 1,746,570
# Non-trainable params: 7,680
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.9931 - accuracy: 0.3043 - val_loss: 1.9969 - val_accuracy: 0.2991
# Epoch 2/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.6229 - accuracy: 0.4299 - val_loss: 1.7788 - val_accuracy: 0.3764
# Epoch 3/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.5061 - accuracy: 0.4713 - val_loss: 1.6137 - val_accuracy: 0.4317
# Epoch 4/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.4248 - accuracy: 0.5015 - val_loss: 1.5220 - val_accuracy: 0.4614
# Epoch 5/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.3591 - accuracy: 0.5268 - val_loss: 1.4784 - val_accuracy: 0.4745
# Epoch 6/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.3019 - accuracy: 0.5467 - val_loss: 1.4495 - val_accuracy: 0.4870
# Epoch 7/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.2511 - accuracy: 0.5667 - val_loss: 1.4324 - val_accuracy: 0.4892
# Epoch 8/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.2033 - accuracy: 0.5843 - val_loss: 1.4141 - val_accuracy: 0.4970
# Epoch 9/10
# 50000/50000 [==============================] - 2s 35us/step - loss: 1.1568 - accuracy: 0.6032 - val_loss: 1.4064 - val_accuracy: 0.4983
# Epoch 10/10
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.1150 - accuracy: 0.6191 - val_loss: 1.3962 - val_accuracy: 0.5049

# %% [markdown]
# ## 請於 BN 放在 Input Layer 後，並比較結果

# %%
from keras.layers import BatchNormalization


def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    
    input_layer = keras.layers.Input(input_shape)
    
    # 3. BN 放在 Input Layer 後
    x = BatchNormalization()(input_layer)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = 512
MOMENTUM = 0.95

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()

optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
   
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,751,178
# Trainable params: 1,745,034
# Non-trainable params: 6,144
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 2s 37us/step - loss: 2.0167 - accuracy: 0.2793 - val_loss: 1.9889 - val_accuracy: 0.3178
# Epoch 2/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.7185 - accuracy: 0.3974 - val_loss: 1.7832 - val_accuracy: 0.4026
# Epoch 3/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.6136 - accuracy: 0.4353 - val_loss: 1.6413 - val_accuracy: 0.4327
# Epoch 4/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.5430 - accuracy: 0.4596 - val_loss: 1.5684 - val_accuracy: 0.4493
# Epoch 5/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.4862 - accuracy: 0.4801 - val_loss: 1.5268 - val_accuracy: 0.4658
# Epoch 6/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.4371 - accuracy: 0.4997 - val_loss: 1.4967 - val_accuracy: 0.4724
# Epoch 7/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.3958 - accuracy: 0.5164 - val_loss: 1.4734 - val_accuracy: 0.4796
# Epoch 8/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.3557 - accuracy: 0.5302 - val_loss: 1.4540 - val_accuracy: 0.4887
# Epoch 9/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.3200 - accuracy: 0.5440 - val_loss: 1.4400 - val_accuracy: 0.4902
# Epoch 10/10
# 50000/50000 [==============================] - 2s 32us/step - loss: 1.2844 - accuracy: 0.5570 - val_loss: 1.4215 - val_accuracy: 0.4988
